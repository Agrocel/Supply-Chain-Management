# %%
import pandas as pd 
import numpy as np

# %%
data_exits = pd.read_csv(r"Z:\Supply-Chain_management(SCM)\Data\Processed\data_25.csv")

# %%
data_new = pd.read_excel(r"Z:\Supply-Chain_management(SCM)\Data\Raw\Sales\Sales-25-Aug.XLSX")

# %%
data_new.columns
# Out:
# Index(['Delivery No', 'Billing Document', 'Billing Date', 'Payer Name',
#        'Inv Net Wt.', 'Basic Value', 'Invoice Value', 'Taxable Value',
#        'Agent Name', 'Service Charge', 'Sales Order No', 'Billing Type',
#        'Sales Organization', 'Distribution Channel', 'Division', 'Plant Code',
#        'Plant Desc', 'ZCST-A/R CST Amt', 'ZVAT-A/R VAT Amt',
#        'ZVAD-A/R Add VAT Amt', 'ZCEP-A/R ECESS Amt', 'ZCEP-A/R HCESS Amt',
#        'ZEXP-A/R BED % Amt', 'Packing Charge', 'Storage Location',
#        'Descr. of Storage Loc.', 'Ship-To-Party Code', 'Ship-To-Party Name',
#        'Ship-To-Party City', 'Customer Group', 'Payer Code', 'Payer City',
#        'Sold-To-Party Code', 'Agent Code', 'Broker City', 'Sold-To-Party Name',
#        'Sold-To-Party City', 'Tin No.', 'CST No.', 'TCS', 'Batch No.',
#        'Mat. Code', 'Mat. Desc.', 'Inv Qty.', 'Inv Qty UOM.', 'Inv Wt.UOM',
#        'Basic Rate', 'Invoice Net Rate', 'Incoterms', 'Customer Region',
#        'Customer Region Desc', 'Region of dlv.plant', 'Del Plant Region Des',
#        'Delivery QTY', 'Cash Discount', 'Sales Tax', 'Serial Number',
#        'Remarks 1', 'Remarks Way Bill Number Remarks', 'Discount',
#        'Rebate/discount', 'FOB(Frt)', 'Excise Value', 'Form Type',
#        'TRANSPORTER CODE', 'TRANSPORTER NAME', 'LRNO', 'Vehicle Number',
#        'Freight', 'Sales Zone', 'CFR/CIF Freight Chrg',
#        'CIF/CI/CIP Insurance Chrg', 'NSM', 'RET/Cash Discount',
#        'RET/ Additional Discount', 'TCS 206C(1H)', 'Zone Description'],
#       dtype='object')

# %%
data_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4093 entries, 0 to 4092
# Data columns (total 77 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Delivery No                      4093 non-null   int64
#  1   Billing Document                 4093 non-null   int64
#  2   Billing Date                     4093 non-null   datetime64[ns]
#  3   Payer Name                       4093 non-null   object
#  4   Inv Net Wt.                      4093 non-null   float64
#  5   Basic Value                      4093 non-null   int64
#  6   Invoice Value                    4093 non-null   float64
#  7   Taxable Value                    4093 non-null   int64
#  8   Agent Name                       0 non-null      float64
#  9   Service Charge                   4093 non-null   float64
#  10  Sales Order No                   4061 non-null   float64
#  11  Billing Type                     4093 non-null   object
#  12  Sales Organization               4093 non-null   int64
#  13  Distribution Channel             4093 non-null   int64
#  14  Division                         4093 non-null   int64
#  15  Plant Code                       4093 non-null   object
#  16  Plant Desc                       4093 non-null   object
#  17  ZCST-A/R CST Amt                 4093 non-null   int64
#  18  ZVAT-A/R VAT Amt                 4093 non-null   int64
#  19  ZVAD-A/R Add VAT Amt             4093 non-null   int64
#  20  ZCEP-A/R ECESS Amt               4093 non-null   int64
#  21  ZCEP-A/R HCESS Amt               4093 non-null   int64
#  22  ZEXP-A/R BED % Amt               4093 non-null   int64
#  23  Packing Charge                   4093 non-null   int64
#  24  Storage Location                 2594 non-null   object
#  25  Descr. of Storage Loc.           2594 non-null   object
#  26  Ship-To-Party Code               4093 non-null   int64
#  27  Ship-To-Party Name               4093 non-null   object
#  28  Ship-To-Party City               4093 non-null   object
#  29  Customer Group                   4071 non-null   object
#  30  Payer Code                       4093 non-null   int64
#  31  Payer City                       4093 non-null   object
#  32  Sold-To-Party Code               4093 non-null   int64
#  33  Agent Code                       0 non-null      float64
#  34  Broker City                      0 non-null      float64
#  35  Sold-To-Party Name               4093 non-null   object
#  36  Sold-To-Party City               4093 non-null   object
#  37  Tin No.                          0 non-null      float64
#  38  CST No.                          0 non-null      float64
#  39  TCS                              4093 non-null   int64
#  40  Batch No.                        2392 non-null   object
#  41  Mat. Code                        4093 non-null   object
#  42  Mat. Desc.                       4093 non-null   object
#  43  Inv Qty.                         4093 non-null   float64
#  44  Inv Qty UOM.                     4093 non-null   object
#  45  Inv Wt.UOM                       4093 non-null   object
#  46  Basic Rate                       4093 non-null   float64
#  47  Invoice Net Rate                 4093 non-null   float64
#  48  Incoterms                        4093 non-null   object
#  49  Customer Region                  4090 non-null   float64
#  50  Customer Region Desc             4090 non-null   object
#  51  Region of dlv.plant              4093 non-null   int64
#  52  Del Plant Region Des             4093 non-null   object
#  53  Delivery QTY                     4093 non-null   float64
#  54  Cash Discount                    4093 non-null   int64
#  55  Sales Tax                        4093 non-null   int64
#  56  Serial Number                    0 non-null      float64
#  57  Remarks 1                        96 non-null     object
#  58  Remarks Way Bill Number Remarks  0 non-null      float64
#  59  Discount                         4093 non-null   int64
#  60  Rebate/discount                  4093 non-null   int64
#  61  FOB(Frt)                         4093 non-null   int64
#  62  Excise Value                     4093 non-null   int64
#  63  Form Type                        22 non-null     object
#  64  TRANSPORTER CODE                 27 non-null     float64
#  65  TRANSPORTER NAME                 27 non-null     object
#  66  LRNO                             27 non-null     object
#  67  Vehicle Number                   27 non-null     object
#  68  Freight                          4093 non-null   int64
#  69  Sales Zone                       4002 non-null   object
#  70  CFR/CIF Freight Chrg             4093 non-null   int64
#  71  CIF/CI/CIP Insurance Chrg        4093 non-null   int64
#  72  NSM                              4093 non-null   float64
#  73  RET/Cash Discount                4093 non-null   int64
#  74  RET/ Additional Discount         4093 non-null   int64
#  75  TCS 206C(1H)                     4093 non-null   int64
#  76  Zone Description                 4002 non-null   object
# dtypes: datetime64[ns](1), float64(18), int64(31), object(27)
# memory usage: 2.4+ MB

# %%
data_excel.sheet_names
# Out:
# ['Sheet1', 'Sheet2', 'Sheet3']

# %%
data_new.to_csv("Z:\Supply-Chain_management(SCM)\Data\Raw\Sales\Sales-25-Aug.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\S'
# <>:1: SyntaxWarning: invalid escape sequence '\S'
# C:\Users\MU_ICT_025\AppData\Local\Temp\ipykernel_14864\756128239.py:1: SyntaxWarning: invalid escape sequence '\S'
#   data_new.to_csv("Z:\Supply-Chain_management(SCM)\Data\Raw\Sales\Sales-25-Aug.csv")
