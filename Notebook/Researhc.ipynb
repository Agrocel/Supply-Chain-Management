# %%
import pandas as pd 
import numpy as np
# Out:
# Running cells with 'venv (Python 3.13.5)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'z:/Supply-Chain_management(SCM)/venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'

# %%
data_exits = pd.read_csv("Z:\Supply-Chain_management(SCM)\Data\Raw\Sales\Sales-20-25(Jan-June).csv")
# Out:
# Running cells with 'venv (Python 3.13.5)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'z:/Supply-Chain_management(SCM)/venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'

# %%
data_new = pd.read_excel("Z:\Supply-Chain_management(SCM)\Data\Raw\Sales\Sales-25-July.XLSX")
