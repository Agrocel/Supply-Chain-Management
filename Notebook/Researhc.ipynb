# %%
import pandas as pd 
import numpy as np

# %%
data_exits = pd.read_csv(r"Z:\Supply-Chain_management(SCM)\Data\Processed\data_25.csv")

# %%
data_new = pd.read_excel(r"Z:\Supply-Chain_management(SCM)\Data\Raw\Sales\Sales-25-Aug.XLSX")

# %%
data_new.head()
# Out:
#    Delivery No  Billing Document Billing Date                     Payer Name  \
# 0    802504433         302500257   2025-08-05  KISAN AGRI CLINIC - ANANTAPUR
# 1    802504433         302500257   2025-08-05  KISAN AGRI CLINIC - ANANTAPUR
# 2    802504433         302500257   2025-08-05  KISAN AGRI CLINIC - ANANTAPUR
# 3    802504433         302500257   2025-08-05  KISAN AGRI CLINIC - ANANTAPUR
# 4    802504434         302500258   2025-08-05                 P.A.C.S MIDJIL
#
#    Inv Net Wt.  Basic Value  Invoice Value  Taxable Value  Agent Name  \
# 0          0.0            0           0.00              0         NaN
# 1         48.0        16800       16632.00          16800         NaN
# 2          0.0            0           0.00              0         NaN
# 3         50.0        19000       18900.00          19000         NaN
# 4        100.0         8800        8130.15           8800         NaN
#
#    Service Charge  ...  Vehicle Number Freight  Sales Zone  \
# ...

# %%
data_excel = pd.ExcelFile("Z:\Supply-Chain_management(SCM)\Data\Raw\Sales\Sales-25-Aug.XLSX")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\S'
# <>:1: SyntaxWarning: invalid escape sequence '\S'
# C:\Users\MU_ICT_025\AppData\Local\Temp\ipykernel_14864\3281161015.py:1: SyntaxWarning: invalid escape sequence '\S'
#   data_excel = pd.ExcelFile("Z:\Supply-Chain_management(SCM)\Data\Raw\Sales\Sales-25-Aug.XLSX")

# %%
data_excel.sheet_names
# Out:
# ['Sheet1', 'Sheet2', 'Sheet3']

# %%
data_new.to_csv("Z:\Supply-Chain_management(SCM)\Data\Raw\Sales\Sales-25-Aug.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\S'
# <>:1: SyntaxWarning: invalid escape sequence '\S'
# C:\Users\MU_ICT_025\AppData\Local\Temp\ipykernel_14864\756128239.py:1: SyntaxWarning: invalid escape sequence '\S'
#   data_new.to_csv("Z:\Supply-Chain_management(SCM)\Data\Raw\Sales\Sales-25-Aug.csv")
